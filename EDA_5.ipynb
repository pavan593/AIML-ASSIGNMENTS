# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-9ff471cb-d4ce-4eae-a70a-b6a2398271bf" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9ff471cb-d4ce-4eae-a70a-b6a2398271bf">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
data = pd.read_csv("data_clean.csv")
data
# Out:
#      Unnamed: 0  Ozone  Solar.R  Wind Temp C Month  Day  Year  Temp Weather
# 0             1   41.0    190.0   7.4     67     5    1  2010    67       S
# 1             2   36.0    118.0   8.0     72     5    2  2010    72       C
# 2             3   12.0    149.0  12.6     74     5    3  2010    74      PS
# 3             4   18.0    313.0  11.5     62     5    4  2010    62       S
# 4             5    NaN      NaN  14.3     56     5    5  2010    56       S
# ..          ...    ...      ...   ...    ...   ...  ...   ...   ...     ...
# 153         154   41.0    190.0   7.4     67     5    1  2010    67       C
# 154         155   30.0    193.0   6.9     70     9   26  2010    70      PS
# 155         156    NaN    145.0  13.2     77     9   27  2010    77       S
# 156         157   14.0    191.0  14.3     75     9   28  2010    75       S
# 157         158   18.0    131.0   8.0     76     9   29  2010    76       C
#
# [158 rows x 10 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  158 non-null    int64
#  1   Ozone       120 non-null    float64
#  2   Solar.R     151 non-null    float64
#  3   Wind        158 non-null    float64
#  4   Temp C      158 non-null    object
#  5   Month       158 non-null    object
#  6   Day         158 non-null    int64
#  7   Year        158 non-null    int64
#  8   Temp        158 non-null    int64
#  9   Weather     155 non-null    object
# dtypes: float64(3), int64(4), object(3)
# memory usage: 12.5+ KB

# %%
print(type(data))
print(data.shape)
print(data.size)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# (158, 10)
# 1580

# %%
data1 = data.drop(['Unnamed: 0',"Temp C"], axis=1,)
data1
# Out:
#      Ozone  Solar.R  Wind Month  Day  Year  Temp Weather
# 0     41.0    190.0   7.4     5    1  2010    67       S
# 1     36.0    118.0   8.0     5    2  2010    72       C
# 2     12.0    149.0  12.6     5    3  2010    74      PS
# 3     18.0    313.0  11.5     5    4  2010    62       S
# 4      NaN      NaN  14.3     5    5  2010    56       S
# ..     ...      ...   ...   ...  ...   ...   ...     ...
# 153   41.0    190.0   7.4     5    1  2010    67       C
# 154   30.0    193.0   6.9     9   26  2010    70      PS
# 155    NaN    145.0  13.2     9   27  2010    77       S
# 156   14.0    191.0  14.3     9   28  2010    75       S
# 157   18.0    131.0   8.0     9   29  2010    76       C
#
# [158 rows x 8 columns]

# %%
data1['Month']=pd.to_numeric(data['Month'],errors='coerce')
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 8 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Ozone    120 non-null    float64
#  1   Solar.R  151 non-null    float64
#  2   Wind     158 non-null    float64
#  3   Month    157 non-null    float64
#  4   Day      158 non-null    int64
#  5   Year     158 non-null    int64
#  6   Temp     158 non-null    int64
#  7   Weather  155 non-null    object
# dtypes: float64(4), int64(3), object(1)
# memory usage: 10.0+ KB

# %%
data1[data1.duplicated(keep = False)]
# Out:
#      Ozone  Solar.R  Wind  Month  Day  Year  Temp Weather
# 150   14.0    191.0  14.3    9.0   28  2010    75       S
# 156   14.0    191.0  14.3    9.0   28  2010    75       S

# %%
data1[data1.duplicated()]
# Out:
#      Ozone  Solar.R  Wind  Month  Day  Year  Temp Weather
# 156   14.0    191.0  14.3    9.0   28  2010    75       S

# %%
# derop duplicated rows
data1.drop_duplicates(keep='first', inplace = True)
data1
# Out:
#      Ozone  Solar.R  Wind  Month  Day  Year  Temp Weather
# 0     41.0    190.0   7.4    5.0    1  2010    67       S
# 1     36.0    118.0   8.0    5.0    2  2010    72       C
# 2     12.0    149.0  12.6    5.0    3  2010    74      PS
# 3     18.0    313.0  11.5    5.0    4  2010    62       S
# 4      NaN      NaN  14.3    5.0    5  2010    56       S
# ..     ...      ...   ...    ...  ...   ...   ...     ...
# 152   20.0    223.0  11.5    9.0   30  2010    68       S
# 153   41.0    190.0   7.4    5.0    1  2010    67       C
# 154   30.0    193.0   6.9    9.0   26  2010    70      PS
# 155    NaN    145.0  13.2    9.0   27  2010    77       S
# 157   18.0    131.0   8.0    9.0   29  2010    76       C
#
# [157 rows x 8 columns]

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 157 entries, 0 to 157
# Data columns (total 8 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Ozone    119 non-null    float64
#  1   Solar.R  150 non-null    float64
#  2   Wind     157 non-null    float64
#  3   Month    156 non-null    float64
#  4   Day      157 non-null    int64
#  5   Year     157 non-null    int64
#  6   Temp     157 non-null    int64
#  7   Weather  154 non-null    object
# dtypes: float64(4), int64(3), object(1)
# memory usage: 11.0+ KB

# %%
data1.isnull().sum()
# Out:
# Ozone      38
# Solar.R     7
# Wind        0
# Month       1
# Day         0
# Year        0
# Temp        0
# Weather     3
# dtype: int64

# %%
cols = data1.columns
colors = ['black', 'yellow']
sns.heatmap(data1[cols].isnull(), cmap=sns.color_palette(colors), cbar=True)
# Out:
# <Axes: >

# %%
median_Ozone = data1["Ozone"].median()
mean_Ozone = data1["Ozone"].mean()
print("Median of Ozone:", median_Ozone)
print("Mean of Ozone:", mean_Ozone)
# Out:
# Median of Ozone: 31.0
# Mean of Ozone: 41.81512605042017

# %%
data1['Ozone'] = data1['Ozone'].fillna(median_Ozone)
data1.isnull().sum()
# Out:
# Ozone      0
# Solar.R    7
# Wind       0
# Month      1
# Day        0
# Year       0
# Temp       0
# Weather    3
# dtype: int64

# %%
# ipython-input-26-73af6b361051
median_Solar_R = data1["Solar.R"].median() # Changed median_Solar.R to median_Solar_R
mean_Solar_R = data1["Solar.R"].mean()   # Changed mean_Solar.R to mean_Solar_R
print("Median of Solar.R:", median_Solar_R)
print("Mean of Solar.R:", mean_Solar_R)
# Out:
# Median of Solar.R: 199.0
# Mean of Solar.R: 185.36666666666667

# %%
# ipython-input-25-73af6b361051
data1['Solar.R'] = data1['Solar.R'].fillna(median_Solar_R) # Changed median_Solar.R to median_Solar_R
data1.isnull().sum()
# Out:
# Ozone      0
# Solar.R    0
# Wind       0
# Month      1
# Day        0
# Year       0
# Temp       0
# Weather    3
# dtype: int64

# %%
data1.head()
# Out:
#    Ozone  Solar.R  Wind  Month  Day  Year  Temp Weather
# 0   41.0    190.0   7.4    5.0    1  2010    67       S
# 1   36.0    118.0   8.0    5.0    2  2010    72       C
# 2   12.0    149.0  12.6    5.0    3  2010    74      PS
# 3   18.0    313.0  11.5    5.0    4  2010    62       S
# 4   31.0    199.0  14.3    5.0    5  2010    56       S

# %%
print(data1["Weather"].value_counts())
mode_weather = data1["Weather"].mode()[0]
print(mode_weather)
# Out:
# Weather
# S     58
# C     49
# PS    47
# Name: count, dtype: int64
# S

# %%
data1["Weather"] = data1["Weather"].fillna(mode_weather)
data1.isnull().sum()
# Out:
# Ozone      0
# Solar.R    0
# Wind       0
# Month      1
# Day        0
# Year       0
# Temp       0
# Weather    0
# dtype: int64

# %% [markdown]
# # New Section

# %%
print(data1["Month"].value_counts())
mode_month = data1["Month"].mode()[0]  # Assign the mode to mode_month
print(mode_month)  # Now print mode_month
# Out:
# Month
# 9.0    33
# 5.0    31
# 7.0    31
# 8.0    31
# 6.0    30
# Name: count, dtype: int64
# 9.0

# %%
data1["Month"] = data1["Month"].fillna(mode_month)
data1.isnull().sum()
# Out:
# Ozone      0
# Solar.R    0
# Wind       0
# Month      0
# Day        0
# Year       0
# Temp       0
# Weather    0
# dtype: int64

# %%
mode_month = data1["Month"].mode()[0]
data1["Month"] = data1["Month"].fillna(mode_month)
data1.isnull().sum()
# Out:
# Ozone      0
# Solar.R    0
# Wind       0
# Month      0
# Day        0
# Year       0
# Temp       0
# Weather    0
# dtype: int64

# %%
data1.reset_index(drop=True)
# Out:
#      Ozone  Solar.R  Wind  Month  Day  Year  Temp Weather
# 0     41.0    190.0   7.4    5.0    1  2010    67       S
# 1     36.0    118.0   8.0    5.0    2  2010    72       C
# 2     12.0    149.0  12.6    5.0    3  2010    74      PS
# 3     18.0    313.0  11.5    5.0    4  2010    62       S
# 4     31.0    199.0  14.3    5.0    5  2010    56       S
# ..     ...      ...   ...    ...  ...   ...   ...     ...
# 152   20.0    223.0  11.5    9.0   30  2010    68       S
# 153   41.0    190.0   7.4    5.0    1  2010    67       C
# 154   30.0    193.0   6.9    9.0   26  2010    70      PS
# 155   31.0    145.0  13.2    9.0   27  2010    77       S
# 156   18.0    131.0   8.0    9.0   29  2010    76       C
#
# [157 rows x 8 columns]

# %%
fig, axes = plt.subplots(2, 1, figsize=(8, 6), gridspec_kw={'height_ratios': [1, 3]})
sns.boxplot(data=data1["Ozone"], ax=axes[0], color='skyblue', width=0.5, orient='h')
axes[0].set_title("Boxplot")
axes[0].set_xlabel("Ozone Levels")
sns.histplot(data=data1["Ozone"], kde=True, ax=axes[1], color='purple', bins=30)
axes[1].set_title("Histogram with KDE")
axes[1].set_xlabel("Ozone Levels")
axes[1].set_ylabel("Frequency")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(6,2))
boxplot_data = plt.boxplot(data1["Ozone"], vert=False)
[item.get_xdata() for item in boxplot_data['fliers']]
# Out:
# [array([115., 135.,  97.,  97.,  85., 108.,  82., 122.,  89., 110., 168.,
#         118.,  84.,  85.,  96.,  91.])]

# %%
data1["Ozone"].describe()
# Out:
# count    157.000000
# mean      39.197452
# std       28.781992
# min        1.000000
# 25%       21.000000
# 50%       31.000000
# 75%       45.000000
# max      168.000000
# Name: Ozone, dtype: float64

# %%
mu = data1["Ozone"].describe()[1]
sigma = data1["Ozone"].describe()[2]

for x in data1["Ozone"]:
    if x < (mu - 3 * sigma) or x > (mu + 3 * sigma):
        print(x)
# Out:
# 135.0
# 168.0
# <ipython-input-55-36de766429ce>:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   mu = data1["Ozone"].describe()[1]
# <ipython-input-55-36de766429ce>:2: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   sigma = data1["Ozone"].describe()[2]

# %%
import scipy.stats as stats
import matplotlib.pyplot as plt

# Create Q-Q plot
plt.figure(figsize=(8, 6))
stats.probplot(data1["Ozone"], dist="norm", plot=plt)
plt.title("Q-Q Plot for Outlier Detection", fontsize=14)
plt.xlabel("Theoretical Quantiles", fontsize=12)
plt.ylabel("Sample Quantiles", fontsize=12)
plt.show()

# %% [markdown]
# Observations from Q-Q plot
#
#  The data does not follow normal distribution as the data points are deviating significantly away from the red line
#  the data shows a right skewed distribution and possible outliers

# %%
sns.violinplot(data=data1["Ozone"], color='lightgreen')
plt.title("Violin Plot")
plt.show()

# %%
sns.violinplot(data=data1, x = "Weather", y="Ozone", palette="Set2")
# Out:
# <ipython-input-33-2ec511c3d915>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=data1, x = "Weather", y="Ozone", palette="Set2")
# <Axes: xlabel='Weather', ylabel='Ozone'>

# %%
sns.swarmplot(data=data1, x = "Weather", y = "Ozone",color="orange",palette="Set2", size=6)
# Out:
# <ipython-input-34-47b3b4291922>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.swarmplot(data=data1, x = "Weather", y = "Ozone",color="orange",palette="Set2", size=6)
# <Axes: xlabel='Weather', ylabel='Ozone'>

# %%
sns.stripplot(data=data1, x="Weather", y="Ozone", color="orange", palette="Set2", size=6)
# Out:
# <ipython-input-36-d43c8fe8d1cc>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.stripplot(data=data1, x="Weather", y="Ozone", color="orange", palette="Set2", size=6)
# <Axes: xlabel='Weather', ylabel='Ozone'>

# %%
sns.kdeplot(data=data1["Ozone"], fill=True, color="skyblue")
# Out:
# <Axes: xlabel='Ozone', ylabel='Density'>

# %%
plt.scatter(data1["Wind"],data1["Temp"])

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 157 entries, 0 to 157
# Data columns (total 8 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Ozone    157 non-null    float64
#  1   Solar.R  157 non-null    float64
#  2   Wind     157 non-null    float64
#  3   Month    157 non-null    float64
#  4   Day      157 non-null    int64
#  5   Year     157 non-null    int64
#  6   Temp     157 non-null    int64
#  7   Weather  157 non-null    object
# dtypes: float64(4), int64(3), object(1)
# memory usage: 15.1+ KB

# %%
data1_numeric = data.iloc[:,[0,1,2,6]]
data1_numeric
# Out:
#      Unnamed: 0  Ozone  Solar.R  Day
# 0             1   41.0    190.0    1
# 1             2   36.0    118.0    2
# 2             3   12.0    149.0    3
# 3             4   18.0    313.0    4
# 4             5    NaN      NaN    5
# ..          ...    ...      ...  ...
# 153         154   41.0    190.0    1
# 154         155   30.0    193.0   26
# 155         156    NaN    145.0   27
# 156         157   14.0    191.0   28
# 157         158   18.0    131.0   29
#
# [158 rows x 4 columns]

# %%
data1_numeric.corr()
# Out:
#             Unnamed: 0     Ozone   Solar.R       Day
# Unnamed: 0    1.000000  0.124515 -0.109520  0.216219
# Ozone         0.124515  1.000000  0.348642 -0.035055
# Solar.R      -0.109520  0.348642  1.000000 -0.154212
# Day           0.216219 -0.035055 -0.154212  1.000000
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['Unnamed: 0'].plot(kind='hist', bins=20, title='Unnamed: 0')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['Ozone'].plot(kind='hist', bins=20, title='Ozone')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_2['Solar.R'].plot(kind='hist', bins=20, title='Solar.R')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_3['Day'].plot(kind='hist', bins=20, title='Day')
# ...

# %% [markdown]
# OBSERVATION
#
# * The highest correlation strength is observed between Ozone and Temperature(0.597087)
# * The next higher correlation strength is observed between Ozone and wind(-0.523738)
# *   The next higher correlation strength is observed between wind and temp(-0.441228)
# * The least correlation strength is observed between solar and wind(-0.055874)

# %%
sns.pairplot(data1_numeric)

# %% [markdown]
# TRANSFORMATIONS

# %%
data2=pd.get_dummies(data1,columns=['Month','Weather'])
data2
# Out:
#      Ozone  Solar.R  Wind  Day  Year  Temp  Month_5.0  Month_6.0  Month_7.0  \
# 0     41.0    190.0   7.4    1  2010    67       True      False      False
# 1     36.0    118.0   8.0    2  2010    72       True      False      False
# 2     12.0    149.0  12.6    3  2010    74       True      False      False
# 3     18.0    313.0  11.5    4  2010    62       True      False      False
# 4     31.0    199.0  14.3    5  2010    56       True      False      False
# ..     ...      ...   ...  ...   ...   ...        ...        ...        ...
# 152   20.0    223.0  11.5   30  2010    68      False      False      False
# 153   41.0    190.0   7.4    1  2010    67       True      False      False
# 154   30.0    193.0   6.9   26  2010    70      False      False      False
# 155   31.0    145.0  13.2   27  2010    77      False      False      False
# 157   18.0    131.0   8.0   29  2010    76      False      False      False
#
# ...
